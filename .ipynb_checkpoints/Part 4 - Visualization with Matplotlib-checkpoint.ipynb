# %% [markdown]
# # Визуализация с помощью библиотеки Matplotlib

# %% [markdown]
# # Общие советы по библиотеке Matplotlib

# %% [markdown]
# ## Импорт matplotlib

# %%
import matplotlib as mplt
import matplotlib.pyplot as plt

# %% [markdown]
# ## Настройка стилей

# %%
# classic - классический стиль библиотеки Matplotlib
plt.style.use('classic')

# %% [markdown]
# ## Использовать show() или не использовать? Как отображать свои графики

# %% [markdown]
# ### Построение графиков из блокнота Ipython

# %%
# %matplotlib inline - построение статических графиков
# %matplotlib inline

# %%
import numpy as np
x = np.linspace(0, 10, 100)

fig = plt.figure()
plt.plot(x, np.sin(x), '-')
plt.plot(x, np.cos(x), '--');

# %% [markdown]
# # Два интерфейса по цене одного

# %% [markdown]
# ## Интерфейс в стиле MATLAB

# %%
plt.figure() # создаем рисунок для графика

# Создаем первую из двух областей графика и задаем текущую ось
plt.subplot(2, 1, 1) # (rows, columns, panel number)
plt.plot(x, np.sin(x))

# Создаем вторую область и задаем текущую ось
plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x));

# %% [markdown]
# ## Объектно-ориентированный интерфейс

# %%
# Сначала создаем сетку графиков
# ax будет массивом из двух объектов Axes
fig, ax = plt.subplots(2)

# Вызываем метод plot() соответствующего объекта
ax[0].plot(x, np.sin(x))
ax[1].plot(x, np.cos(x));

# %% [markdown]
# # Простые линейные графики

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

# %%
fig = plt.figure() # создание рисунка
ax = plt.axes() # создание системы координат

x = np.linspace(0, 10, 1000)
ax.plot(x, np.sin(x)); # plot функция для построения графика данных

# %%
plt.plot(x, np.sin(x)); # тоже самое через интерфейс pylab

# %%
plt.plot(x, np.sin(x)) # простой рисунок с несколькими линиями
plt.plot(x, np.cos(x)); # можно несколько раз вызвать функцию plot

# %% [markdown]
# ## Настройка графиков: цвета и стили линий

# %%
plt.plot(x, np.sin(x - 0), color='blue') # задаем цвет по названию
plt.plot(x, np.sin(x - 1), color='g') # кратикий код цвета (rgbcmyk)
plt.plot(x, np.sin(x - 2), color='0.75') # Шкала оттенков серого цвета, значение в диапазоне от 0 до 1
plt.plot(x, np.sin(x - 3), color='#FFDD44') # 16 разрядный код
plt.plot(x, np.sin(x - 4), color=(1.0, 0.2, 0.3)) # кортеж rgb, значения от 0 до 1
plt.plot(x, np.sin(x - 5), color='chartreuse'); # поддерживаются все названия цветов html

# %%
plt.plot(x, x + 0, linestyle='solid') # стиль линий через слово linestyle
plt.plot(x, x + 1, linestyle='dashed')
plt.plot(x, x + 2, linestyle='dashdot')
plt.plot(x, x + 3, linestyle='dotted');

# %%
# можно использовать и следующие сокращенные коды
plt.plot(x, x + 4, linestyle='-') # сплошная линия
plt.plot(x, x + 5, linestyle='--') # штржихованная линия
plt.plot(x, x + 6, linestyle='-.') # штрихпунктирная линия
plt.plot(x, x + 7, linestyle=':'); # пунктирная линия

# %%
# можно объединить задание кодов linestyle и color в одном неключевом аргументе
plt.plot(x, x + 0, '-g') # сплошная линия зеленого цвета
plt.plot(x, x + 1, '--c') # штрихованная линия голубого цвета
plt.plot(x, x + 2, '-.k') # штрихованная линия черного цвета
plt.plot(x, x + 3, ':r'); # пунктирная линия красного цвета

# %% [markdown]
# ## Настройка графика: пределы осей координат

# %%
plt.plot(x, np.sin(x))

plt.xlim(-1, 11) # x от -1 до 11
plt.ylim(-1.5, 1.5) # y от -1.5 до 1.5
# Out:
# (-1.5, 1.5)

# %%
plt.plot(x, np.sin(x))

# зеркальное отображение, аргкменты в обратном порядке
plt.xlim(10, 0)
plt.ylim(1.2, -1,2);

# %%
plt.plot(x, np.sin(x))
# axis задаем границы путем списка [xmin, xmax, ymin, ymax]
plt.axis([-1, 11, -1.5, 1.5]);

# %%
plt.plot(x, np.sin(x))
# плотная подгонка осей под график
plt.axis('tight');

# %%
plt.plot(x, np.sin(x))
plt.axis('equal')
# Out:
# (0.0, 10.0, -1.0, 1.0)

# %% [markdown]
# ## Метки на графиках

# %%
plt.plot(x, np.sin(x))
plt.title('A Sine Curve') # синусоидальная кривая
plt.xlabel('x')
plt.ylabel('sin(x)')
# Out:
# Text(0, 0.5, 'sin(x)')

# %%
plt.plot(x, np.sin(x), '-g', label='sin(x)')
plt.plot(x, np.cos(x), ':b', label='cos(x)')
plt.axis('equal')
plt.legend();

# %%
ax = plt.axes()
ax.plot(x, np.sin(x))
ax.set(xlim=(0, 10), ylim=(-2, 2), xlabel='x', ylabel='sin(x)', title='A simple Peot');

# %% [markdown]
# # Простые диаграмы рассеяния

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

# %% [markdown]
# ## Построение диаграмм рассеяния с помощью функции plt.plot

# %%
x = np.linspace(0, 10, 30)
y = np.sin(x)

plt.plot(x, y, 'o', color='black')

# %%
rng = np.random.RandomState(0)
for marker in ['o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd']:
    plt.plot(rng.rand(5), rng.rand(5), marker, label=f"marker='{marker}'")
plt.legend(numpoints=1)
plt.xlim(0, 1.8)
# Out:
# (0.0, 1.8)

# %%
plt.plot(x, y, '-ok'); # линия (-), маркер круга (о), черный цвет (k)

# %%
plt.plot(x, y, '-p', color='gray',
         markersize=15, linewidth=4,
         markerfacecolor='white',
         markeredgecolor='gray',
         markeredgewidth=2)
plt.ylim(-1.2, 1.2);

# %% [markdown]
# ## Построение диаграмм рассеяния с помощью функции plt.scatter

# %%
plt.scatter(x, y, marker='o');

# %%
rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000 * rng.rand(100)

plt.scatter(x, y, c=colors, s=sizes, alpha=0.3, cmap='viridis')
plt.colorbar(); # отображаем цветовую шкалу
# Out:
# /tmp/ipykernel_7036/3130088989.py:8: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar(); # отображаем цветовую шкалу

# %%
from sklearn.datasets import load_iris
iris = load_iris()

features = iris.data.T
plt.scatter(features[0], features[1], alpha=0.2,
            s=100*features[3], c=iris.target, cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1]);

# %% [markdown]
# # Визуализация погрешностей

# %% [markdown]
# ## Простые планки погрешностей

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

x = np.linspace(0, 10, 50)
dy = 0.8
y = np.sin(x) + dy * np.random.randn(50)

plt.errorbar(x, y, yerr=dy, fmt='.k');

# %%
plt.errorbar(x, y, yerr=dy, fmt='o', color='black', ecolor='lightgray', elinewidth=3, capsize=0);

# %% [markdown]
# ## Непрерывные погрешности

# %%
from sklearn.gaussian_process import GaussianProcessRegressor

# define the model and draw some data
model = lambda x: x * np.sin(x)
xdata = np.array([1, 3, 5, 6, 8])
ydata = model(xdata)

# Compute the Gaussian process fit
gp = GaussianProcessRegressor(corr='cubic', theta0=1e-2, thetaL=1e-4, thetaU=1E-1,
                     random_start=100)
gp.fit(xdata[:, np.newaxis], ydata)

xfit = np.linspace(0, 10, 1000)
yfit, MSE = gp.predict(xfit[:, np.newaxis], eval_MSE=True)
dyfit = 2 * np.sqrt(MSE)  # 2*sigma ~ 95% confidence region
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [33], in <cell line: 9>()
#       6 ydata = model(xdata)
#       8 # Compute the Gaussian process fit
# ----> 9 gp = GaussianProcessRegressor(corr='cubic', theta0=1e-2, thetaL=1e-4, thetaU=1E-1,
#      10                      random_start=100)
#      11 gp.fit(xdata[:, np.newaxis], ydata)
#      13 xfit = np.linspace(0, 10, 1000)
#
# TypeError: __init__() got an unexpected keyword argument 'corr'

# %% [markdown]
# # Графики плотности и контурные графики

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import numpy as np

# %% [markdown]
# ### визуализация трехмерных функций

# %%
def f(x, y):
    return np.sin(x) ** 10 + np.cos(10 + y * x) * np.cos(x)

# %%
x = np.linspace(0, 5, 50)
y = np.linspace(0, 5, 40)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

# %%
plt.contour(X, Y, Z, colors='black');

# %%
plt.contour(X, Y, Z, 20, cmap='RdGy');

# %%
plt.contourf(X, Y, Z, 20, cmap='RdGy')
plt.colorbar();

# %%
plt.imshow(Z, extent=[0, 5, 0, 5], origin='lower',
           cmap='RdGy')
plt.colorbar()
plt.axis(aspect='image');

# %%
contours = plt.contour(X, Y, Z, 3, colors='black')
plt.clabel(contours, inline=True, fontsize=8)

plt.imshow(Z, extent=[0, 5, 0, 5], origin='lower', cmap='RdGy', alpha=0.5)
plt.colorbar()

# %% [markdown]
# # Гистрограммы, разбиение по интервалам и плотность

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

data = np.random.randn(1000)

# %%
plt.hist(data);

# %%
plt.hist(data, bins=30, density=True, alpha=0.5,
         histtype='stepfilled', color='steelblue',
         edgecolor='none');

# %%
x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)
kwargs = dict(histtype='stepfilled', alpha=0.3, density=True, bins=40)

plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs);

# %%
counts, bin_edges = np.histogram(data, bins=5)
print(counts)

# %% [markdown]
# ## Двумерные гистрограммы и разбиение по интервалам

# %%
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 10000).T

# %% [markdown]
# ### Функция plt.gist2d: двумерная гистограмма

# %%
plt.hist2d(x, y, bins=30, cmap='Blues')
cb = plt.colorbar()
cb.set_label('count in bin') # Количество в интервале

# %%
counts, xedges, yedeges = np.histogram2d(x, y, bins=30)

# %% [markdown]
# ### Функция plt.hexbin: гексагональное разбиение по интервалам

# %%
plt.hexbin(x, y, gridsize=30, cmap='Blues')
cb = plt.colorbar(label='count in bin') # количество в интервале

# %% [markdown]
# ### Ядерная оценка плотности распределения

# %%
from scipy.stats import gaussian_kde

# Выполняем подбор на массиве размера [ndim, nsamples]
data = np.vstack([x, y])
kde = gaussian_kde(data)

# вычисляем на регулярной координатной сетке
xgrid = np.linspace(-3.5, 3.5, 40)
ygrid = np.linspace(-6, 6, 40)
Xgrid, Ygrid = np.meshgrid(xgrid, ygrid)
Z = kde.evaluate(np.vstack([Xgrid.ravel(), Ygrid.ravel()]))

# Выводим график результата в виде изображения
plt.imshow(Z.reshape(Xgrid.shape),
           origin='lower', aspect='auto',
           extent=[-3.5, 3.5, -6, 6],
           cmap='Blues')
cb = plt.colorbar()
cb.set_label('dendity') # Плотность

# %% [markdown]
# # Пользовательская настройка легенд на графиках

# %%
import matplotlib.pyplot as plt
plt.style.use('classic')

# %matplotlib inline
import numpy as np

x = np.linspace(0, 10, 1000)
fig, ax = plt.subplots()
ax.plot(x, np.sin(x), '-b', label='Sine') # Синус
ax.plot(x, np.cos(x), '--r', label='Cosin') # Косинус
ax.axis('equal')
leg = ax.legend();

# %%
ax.legend(loc='upper left', frameon=False)
fig

# %%
ax.legend(frameon=False, loc='lower center', ncol=2)
fig

# %%
ax.legend(fancybox=True, framealpha=1, shadow=True, borderpad=1)
fig

# %% [markdown]
# ## Выбор элементов для легенды

# %%
y = np.sin(x[:, np.newaxis] + np.pi * np.arange(0, 2, 0.5))
lines = plt.plot(x, y)

# lines представляет собой список экземаляров класса plt.Line2D
plt.legend(lines[:2], ['first', 'second']); # первый, второй

# %%
plt.plot(x, y[:, 0], label='first')
plt.plot(x, y[:, 1], label='second')
plt.plot(x, y[:, 2:])
plt.legend(framealpha=1, frameon=True);

# %% [markdown]
# ## Задание легенды для точек различного размера

# %%
import pandas as pd
cities = pd.read_csv('data/california_cities.csv')

# Extract the data we're interested in
lat, lon = cities['latd'], cities['longd']
population, area = cities['population_total'], cities['area_total_km2']

# Scatter the points, using size and color but no label
plt.scatter(lon, lat, label=None,
            c=np.log10(population), cmap='viridis',
            s=area, linewidth=0, alpha=0.5)
plt.axis('equal')
plt.xlabel('longitude')
plt.ylabel('latitude')
plt.colorbar(label='log$_{10}$(population)')
plt.clim(3, 7)

# Here we create a legend:
# we'll plot empty lists with the desired size and label
for area in [100, 300, 500]:
    plt.scatter([], [], c='k', alpha=0.3, s=area,
                label=str(area) + ' km$^2$')
plt.legend(scatterpoints=1, frameon=False, labelspacing=1, title='City Area')

plt.title('California Cities: Area and Population');

# %% [markdown]
# ## Отображение нескольких легенд

# %%
fig, ax = plt.subplots()

lines = []
styles = ['-', '--', '-.', ':']
x = np.linspace(0, 10, 1000)

for i in range(4):
    lines += ax.plot(x, np.sin(x - i * np.pi / 2),
                     styles[i], color='black')
ax.axis('equal')

# задаем линии и метки первой легенды
ax.legend(lines[:2], ['line A', 'line B'],
          loc='upper right', frameon=False)

# создаем вторую легенду и добавляем рисователь вручную
from matplotlib.legend import Legend
leg = Legend(ax, lines[2:], ['line C', 'line D'], 
             loc='lower right', frameon=False)
ax.add_artist(leg);

# %% [markdown]
# # Пользовательские настройки шкал цветов

# %%
import matplotlib.pyplot as plt
plt.style.use('classic')
# %matplotlib inline
import numpy as np

# %%
x = np.linspace(0, 10, 1000)
I = np.sin(x) * np.cos(x[:, np.newaxis])

# %%
plt.imshow(I)
plt.colorbar();

# %%
plt.imshow(I, cmap='gray');

# %% [markdown]
# ## Выбор карты цветов

# %%
from matplotlib.colors import LinearSegmentedColormap

def grayscale_cmap(cmap):
    """ Возвращает версию в оттенках серого заданной карты цветов """
    cmap = plt.cm.get_cmap(cmap)
    colors = cmap(np.arange(cmap.N))
    
    # Преобразуем RGBA в воспринимаемую глазом светимость серого цвета
    RGB_weight = [0.299, 0.587, 0.114]
    luminance = np.sqrt(np.dot(colors[:, :3] ** 2, RGB_weight))
    colors[:, :3] = luminance[:, np.newaxis]
    
    return LinearSegmentedColormap.from_list(cmap.name + "_gray",    colors, cmap.N)

def view_colormap(cmap):
    """ Рисует карту цветов в эквивалентных оттенках серого """
    cmap = plt.cm.get_cmap(cmap)
    colors = cmap(np.arange(cmap.N))
    
    cmap = grayscale_cmap(cmap)
    grayscale = cmap(np.arange(cmap.N))
    
    fig, ax = plt.subplots(2, figsize=(6, 2),
                           subplot_kw=dict(xticks=[], yticks=[]))
    ax[0].imshow([colors], extent=[0, 10, 0, 1])
    ax[1].imshow([grayscale], extent=[0, 10, 0, 1])

# %%
view_colormap('jet')

# %%
view_colormap('viridis')

# %%
view_colormap('cubehelix')

# %%
view_colormap('RdBu')

# %% [markdown]
# ## Ограничения и расширенные возможности по использованию цветов

# %%
# создаем шум размером 1% от пикселов изображения
speckles = (np.random.random(I.shape) < 0.01)
I[speckles] = np.random.normal(0, 3, np.count_nonzero(speckles))

plt.figure(figsize=(10, 3.5))

plt.subplot(1, 2, 1)
plt.imshow(I, cmap='RdBu')
plt.colorbar()

plt.subplot(1, 2, 2)
plt.imshow(I, cmap='RdBu')
plt.colorbar(extend='both')
plt.clim(-1, 1);

# %% [markdown]
# ## дискретные шкалы цветов

# %%
plt.imshow(I, cmap=plt.cm.get_cmap('Blues', 6))
plt.colorbar()
plt.clim(-1, 1);

# %% [markdown]
# ## Пример: рускописные цифрв
